# %% [markdown]
# # FP Growth

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this tutorial, we will be learning about the FP Growth algorithm. It is used for Association rule mining and Market Basket Analysis.

# %% [markdown]
# Frequent Itemset Mining and Basket Analysis - The process of identifying the frequently occurring product combinations in order to recommend or to rearrange items in both online and offline shopping.

# %% [markdown]
# For example, if we know that customers who buy milk also buy yoghurt, we can promote the yoghurt to increase the sales. Your amazon recommendations like "Frequently bought together" is on of the finest examples.

# %% [markdown]
# Please find the link below for the tutorial on FP Growth by manual calculation  - https://www.geeksforgeeks.org/ml-frequent-pattern-growth-algorithm/

# %% [markdown]
# Some important terms

# %% [markdown]
#  Support - Support says how popular an itemset is,  which is measured by the proportion of transactions in which an itemset appears.

# %% [markdown]
# Confidence - How likely item Y is purchased when item X is purchased, expressed as {X → Y}.

# %% [markdown]
# Lift -  How likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. When lift > 1 then the rule is better at predicting the result than guessing where as when lift < 1, the rule is doing worse than informed guessing.

# %% [markdown]
# Let's now use a dataset and make the market basket analysis and run FP growth algorithm in python

# %% [markdown]
# ## Install packages

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting scipy>=1.16.3 (from mlxtend)
#   Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.5.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from mlxtend) (3.11.0)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\librown\appdata\roaming\python\python312\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\librown\appdata\roaming\python\python312\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.15.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\librown\.conda\envs\python-ds\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 23.3 MB/s  0:00:00
# Downloading numpy-2.5.1-cp312-cp312-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -------------------------- ------------- 8.4/12.4 MB 39.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 41.0 MB/s  0:00:00
# Downloading scipy-1.18.0-cp312-cp312-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    --------- ------------------------------ 8.9/36.6 MB 42.6 MB/s eta 0:00:01
#    ------------------- -------------------- 17.8/36.6 MB 43.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 27.0/36.6 MB 43.8 MB/s eta 0:00:01
#    ------------------------------------- -- 34.3/36.6 MB 41.9 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 40.1 MB/s  0:00:00
# Installing collected packages: numpy, scipy, mlxtend
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 1.26.4
#
#    ---------------------------------------- 0/3 [numpy]
#     Uninstalling numpy-1.26.4:
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#   Attempting uninstall: scipy
#    ---------------------------------------- 0/3 [numpy]
#     Found existing installation: scipy 1.15.3
#    ---------------------------------------- 0/3 [numpy]
#    ------------- -------------------------- 1/3 [scipy]
#     Uninstalling scipy-1.15.3:
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#       Successfully uninstalled scipy-1.15.3
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    -------------------------- ------------- 2/3 [mlxtend]
#    ---------------------------------------- 3/3 [mlxtend]
#
# Successfully installed mlxtend-0.25.0 numpy-2.4.4 scipy-1.16.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.13.4 which is incompatible.
# sklearn-compat 0.1.5 requires scikit-learn<1.9,>=1.2, but you have scikit-learn 1.9.0 which is incompatible.

# %%
# Importing libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\__init__.py:85
#      58     major, minor, *_ = sys.version_info
#      59     msg = f"""
#      60
#      61 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     82 Original error was: {exc}
#      83 """
# ---> 85     raise ImportError(msg) from exc
#      86 finally:
#      87     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python 3.12 from "C:\Users\librown\.conda\envs\Python-DS\python.exe"
#   * The NumPy version is: "1.26.4"
#
# and make sure that they are the versions you expect.
#
# Please carefully study the information and documentation linked above.
# This is unlikely to be a NumPy issue but will be caused by a bad install
# or environment on your machine.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~\.conda\envs\Python-DS\Lib\site-packages\numpy\_core\__init__.py:85
#      58     major, minor, *_ = sys.version_info
#      59     msg = f"""
#      60
#      61 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     82 Original error was: {exc}
#      83 """
# ---> 85     raise ImportError(msg) from exc
#      86 finally:
#      87     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python 3.12 from "C:\Users\librown\.conda\envs\Python-DS\python.exe"
#   * The NumPy version is: "1.26.4"
#
# and make sure that they are the versions you expect.
#
# Please carefully study the information and documentation linked above.
# This is unlikely to be a NumPy issue but will be caused by a bad install
# or environment on your machine.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Importing libraries
# ----> 2 import pandas as pd
#       3 from mlxtend.preprocessing import TransactionEncoder
#
# File ~\.conda\envs\Python-DS\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
#      76     IntervalDtype,
#      77     DatetimeTZDtype,
#      78     StringDtype,
#      79     BooleanDtype,
#      80     # missing
#      81     NA,
#      82     isna,
#      83     isnull,
#      84     notna,
#      85     notnull,
#      86     # indexes
#      87     Index,
#      88     CategoricalIndex,
#      89     RangeIndex,
#      90     MultiIndex,
#      91     IntervalIndex,
#      92     TimedeltaIndex,
#      93     DatetimeIndex,
#      94     PeriodIndex,
#      95     IndexSlice,
#      96     # tseries
#      97     NaT,
#      98     Period,
#      99     period_range,
#     100     Timedelta,
#     101     timedelta_range,
#     102     Timestamp,
#     103     date_range,
#     104     bdate_range,
#     105     Interval,
#     106     interval_range,
#     107     DateOffset,
#     108     # conversion
#     109     to_numeric,
#     110     to_datetime,
#     111     to_timedelta,
#     112     # misc
#     113     Flags,
#     114     Grouper,
#     115     factorize,
#     116     unique,
#     117     value_counts,
#     118     NamedAgg,
#     119     array,
#     120     Categorical,
#     121     set_eng_float_format,
#     122     Series,
#     123     DataFrame,
#     124 )
#     126 from pandas.core.dtypes.dtypes import SparseDtype
#     128 from pandas.tseries.api import infer_freq
#
# File ~\.conda\envs\Python-DS\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)     14     PeriodDtype,
#      15 )
#
# File ~\.conda\envs\Python-DS\Lib\site-packages\pandas\_libs\__init__.py:17
#      13 # Below imports needs to happen first to ensure pandas top level
#      14 # module gets monkeypatched with the pandas_datetime_CAPI
#      15 # see pandas_datetime_exec in pd_datetime.c
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
# ---> 17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
#      18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# ImportError: numpy._core.multiarray failed to import

# %% [markdown]
# ## Loading data

# %% [markdown]
# Now we will load the real transactional bakery data and calculate the product association rules and see how we can consume the output.

# %% [markdown]
# This dataset is created on the basis of transactions that have happened in "The Bakery" at C4C, CU Boulder.

# %%
# Load the dataset
df = pd.read_csv('bakery_data.csv')

# %%
df.head()

# %% [markdown]
# ## Preprocessing data

# %% [markdown]
# Change the data frame's column names and the data to lowercase

# %%
df = df.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
# Summary of variables and the datatype
df.info()

# %% [markdown]
# Let's check on some null values if any.

# %%
df.isnull().sum()

# %%
df['TransactionId'].value_counts()

# %% [markdown]
# Getting the list of transactions

# %% [markdown]
# Let's now create a list of items for each transaction that can be used as training set to create association rules.

# %% [markdown]
# One-hot encoding transaction data

# %% [markdown]
# We need to convert the categorical data to numerical data to generate the rules. Hence we apply one hot encoding. Learn more about one hot encoding at - https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/

# %% [markdown]
# For one One-hot-encoding using TransactionEncoder refer - https://www.anycodings.com/questions/one-hot-encoding-using-transactionencoder-for-lists-with-different-number-of-elements

# %%
def onehot_encoding_transactions(transactions_column):
    transactions = transactions_column.apply(lambda t: str(t).split(','))
    encoder = TransactionEncoder().fit(transactions)
    onehot = encoder.transform(transactions)
    onehot = pd.DataFrame(onehot, columns = encoder.columns_)
    return onehot

onehotencoded_bakery = onehot_encoding_transactions(df['Transaction'])
onehotencoded_bakery

# %% [markdown]
# ## Ready to run

# %% [markdown]
# Run the FP-growth algorithm

# %% [markdown]
# Let's now generate association rules using FP-growth algorithm.

# %%
from mlxtend.frequent_patterns import fpgrowth
# Compute frequent items using the FP-growth algorithm
frequent_itemsets = fpgrowth(onehotencoded_bakery, min_support = 0.05, use_colnames = True)
frequent_itemsets.sort_values('support', ascending = False)

# %% [markdown]
# Let's now see the frequent itemsets

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets

# %% [markdown]
# Let's now see itemsets with single and multiple items using value_counts()

# %%
frequent_itemsets['length'].value_counts()

# %% [markdown]
# Calculate association rules

# %%
from mlxtend.frequent_patterns import association_rules
# Compute all association rules for frequent_itemsets
rules = association_rules(frequent_itemsets, metric = 'lift', min_threshold = 1.0)
rules

# %% [markdown]
# The rule of "sherpa chai,chocochip cookie and ice mocha" has the highest confidence level (48..7%). The link between herpa chai,chocochip cookie and ice mocha just be a coincidence since both goods are commonly seen in all transactions (see frequent itemsets). Lift exceeds 1.0. This does give us a high degree of confidence on the association rule we suggested.

# %% [markdown]
# Interesting Read - https://www.linkedin.com/pulse/market-basket-analysis-why-lift-odd-metric-nadamuni-ramesh/

# %% [markdown]
# Let's see the application side now i.e bundling with the help of a heatmap.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Transform data to matrix format and generate heatmap
pivot = rules.pivot(index='consequents', columns='antecedents', values='support')
# sns.heatmap(pivot)

# Generate a heatmap with annotations on and the colorbar off
plt.figure(figsize=(22,12))
plt.title("Heatmap showing support values for one item sets {antecendent} -> {consequent}\n", size = 20)
sns.heatmap(pivot, annot = True, cbar = True, cmap='GnBu')

# Format and display plot
plt.yticks(rotation=0, size = 16)
plt.xticks(rotation=60, size = 16)
plt.show()

# %% [markdown]
# The heatmap above shows values of support for the association rules. Darker the color, higher the intensity. We can see the high support for the association rule {Ice mocha -> choco chip cookie} and vice-versa. Hence we can bundle these two and sell together!

# %% [markdown]
# ## Congratulations!

# %% [markdown]
# FP Growth Algorithm by Ajay Sadananda is licensed under [CC BY NC SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/).

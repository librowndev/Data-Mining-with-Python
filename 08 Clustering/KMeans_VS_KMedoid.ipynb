# %% [markdown]
# # K-Means and K-Medoid
# We learned both K-Means and K-Medoid as basic clustering methods. Let's play with them and observe the differences.

# %% [markdown]
# ## Prepare the packages
#
#
# *   K-Means is included in sklearn package, we can import it directly.
# *   K-Medoid is included in sklearn extra package, we should install it first, then import it.
# *   We will need numpy and pandas to create some dummy dataset
# *   We will need seaborn for visualize the result.

# %%
#!pip install scikit-learn-extra
#!pip install seaborn

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
#import KMedoids from sklearn_extra.cluster
import seaborn as sns

# %%
from sklearn.cluster import KMeans
import numpy as np

# 1. Prepare data
X = np.array([[1, 2], [1, 4], [1, 0], [10, 2], [10, 4], [10, 0]])

# 2. Define model (choosing K=2 clusters)
kmeans = KMeans(n_clusters=2, random_state=0, n_init="auto")

# 3. Fit the model and predict clusters
kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

print(f"Labels: {labels}")
print(f"Centroids:\n{centroids}")
# Out:
# Labels: [1 1 1 0 0 0]
# Centroids:
# [[10.  2.]
#  [ 1.  2.]]

# %% [markdown]
# # Round 1: Let's create some simple dataset.
# For visualization purpose, we create datapoints with 2 dimensions.

# %% [markdown]
# ### Create 3 clusters of data points.
# Each cluster has 1000 data points, each data point has 2 dimensions. Data points has normal distribution with specified mean and std.

# %%
c1 = np.random.normal(5, 3, (100, 2))
c2 = np.random.normal(15, 5, (100, 2))
c3 = np.random.normal(-5, 2, (100, 2))
d = np.concatenate((c1, c2, c3), axis = 0)
d.shape
# Out:
# (300, 2)

# %% [markdown]
# ### Let's visualize the dataset using Seaborn

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df = pd.DataFrame(d)

# %%
# This forces the visual layout to 2 decimals, regardless of underlying column type
df.style.format("{:,.2f}", na_rep="-")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5f74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5f74_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e5f74_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5f74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5f74_row0_col0" class="data row0 col0" >2.81</td>
#       <td id="T_e5f74_row0_col1" class="data row0 col1" >8.60</td>
#     </tr>
#     <tr>
#       <th id="T_e5f74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5f74_row1_col0" class="data row1 col0" >6.36</td>
#       <td id="T_e5f74_row1_col1" class="data row1 col1" >2.60</td>
#     </tr>
#     <tr>
#       <th id="T_e5f74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5f74_row2_col0" class="data row2 col0" >8.10</td>
# ...

# %%
#pd.options.display.float_format = '{:,.2f}'.format
df = pd.DataFrame(d, columns = ['x', 'y'])
df
# Out:
#         x     y
# 0    2.81  8.60
# 1    6.36  2.60
# 2    8.10  8.92
# 3    0.47  6.67
# 4    7.93  1.36
# ..    ...   ...
# 295 -5.44 -8.21
# 296 -4.61 -4.56
# 297 -7.18 -7.51
# 298 -5.56 -3.13
# 299 -5.57 -6.14
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(data = df, x = df['x'], y = df['y'])
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(data = df, x = df['x'], y = df['y'])
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Let's train a model using KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(d)

# %%
#sns.scatterplot(data = d, x = d[:,0], y = d[:,1],hue = kmeans.predict(d))
sns.scatterplot(data = df, x = df['x'], y = df['y'], hue = kmeans.predict(df))
# Out:
# C:\Users\librown\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2820: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Lets train a model using KMedoid

# %%
#!pip install scikit-learn-extra

# %%
from sklearn_extra.cluster import KMedoids
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from sklearn_extra.cluster import KMedoids
#
# ModuleNotFoundError: No module named 'sklearn_extra'

# %%
# Use the implementation above, then:
kmedoids = KMedoids(n_clusters=3, random_state=0)
kmedoids.fit(X)
labels = kmedoids.labels_
centers = kmedoids.cluster_centers_

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = d, x = d[:,0], y = d[:,1],hue = kmedoids.predict(d))

# %% [markdown]
# ## Conclusion: KMean and KMedoid did equaly well for this dataset.

# %% [markdown]
# #Round 2: Let us add one outlier to the dataset

# %% [markdown]
# ### Create the same random clusters

# %%
c1 = np.random.normal(5, 3, (100, 2))
c2 = np.random.normal(15, 5, (100, 2))
c3 = np.random.normal(-5, 2, (100, 2))

# %% [markdown]
# ### Create an outlier.
# The outlier is far away from all other data points

# %%
outlier = np.array([[100, 100]])

# %%
d = np.concatenate((c1, c2, c3, outlier), axis = 0)

# %% [markdown]
# ### Visualize the dataset

# %%
sns.scatterplot(data = d, x = d[:,0], y = d[:,1])

# %% [markdown]
# ### Train a model using KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(d)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = d, x = d[:,0], y = d[:,1], hue = kmeans.predict(d))

# %% [markdown]
# ### Train a model using KMedoids

# %%
kmedoids = KMedoids(n_clusters=3).fit(d)

# %% [markdown]
# ###visualize the result

# %%
sns.scatterplot(data = d, x = d[:,0], y = d[:,1],hue = kmedoids.predict(d))

# %% [markdown]
# ### Conclusion: KMedoid did well even with an outlier. KMeans failed

# %% [markdown]
# #Round 3: Let's create a more realistic dataset using pandas

# %% [markdown]
# ## create a dataset

# %%
df = pd.DataFrame({'x': np.random.normal(5, 3, (100)), 'y': np.random.normal(-2, 2, (100))})
df = df.append(pd.DataFrame({'x': np.random.normal(15, 2, (100)), 'y': np.random.normal(22, 2, (100))}))
df = df.append(pd.DataFrame({'x': np.random.normal(-5, 3, (100)), 'y': np.random.normal(8, 2, (100))}))

# %% [markdown]
# ### Visualize the dataset

# %%
sns.relplot(data = df, x = 'x', y = 'y')

# %% [markdown]
# ### Train a model using KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmeans.predict(df))

# %% [markdown]
# ### Train a model using KMdoids

# %%
kmedoids = KMedoids(n_clusters=3).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmedoids.predict(df))

# %% [markdown]
# ### Conclusion: KMeans and KMedoid did equally well.

# %% [markdown]
# #Round 4: Let's add an outlier

# %% [markdown]
# ## Create a dataset with an outlier

# %%
df = pd.DataFrame({'x': np.random.normal(5, 3, (100)), 'y': np.random.normal(-2, 2, (100))})
df = df.append(pd.DataFrame({'x': np.random.normal(15, 2, (100)), 'y': np.random.normal(22, 2, (100))}))
df = df.append(pd.DataFrame({'x': np.random.normal(-5, 3, (100)), 'y': np.random.normal(8, 2, (100))}))
#outlier
df = df.append(pd.DataFrame({'x': [100], 'y': [100]}))

# %% [markdown]
# ### Visualize the dataset

# %%
sns.relplot(data = df, x = 'x', y = 'y')

# %% [markdown]
# ### Train a model using KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmeans.predict(df))

# %% [markdown]
# ### Train a model using KMdoids

# %%
kmedoids = KMedoids(n_clusters=3).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmedoids.predict(df))

# %% [markdown]
# ### Conclusion: KMedoid did well even with an outlier. KMeans failed

# %% [markdown]
# #Round 5: Let's add two outliers

# %% [markdown]
# ## Create a dataset with an outlier

# %%
df = pd.DataFrame({'x': np.random.normal(5, 3, (100)), 'y': np.random.normal(-2, 2, (100))})
df = df.append(pd.DataFrame({'x': np.random.normal(15, 2, (100)), 'y': np.random.normal(22, 2, (100))}))
df = df.append(pd.DataFrame({'x': np.random.normal(-5, 3, (100)), 'y': np.random.normal(8, 2, (100))}))
#outlier
df = df.append(pd.DataFrame({'x': [200], 'y': [200]}))
df = df.append(pd.DataFrame({'x': [-200], 'y': [-200]}))

# %% [markdown]
# ### Visualize the dataset

# %%
sns.relplot(data = df, x = 'x', y = 'y')

# %% [markdown]
# ### Train a model using KMeans

# %%
kmeans = KMeans(n_clusters=3).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmeans.predict(df))

# %% [markdown]
# ### Train a model using KMdoids

# %%
kmedoids = KMedoids(n_clusters=3).fit(df)

# %% [markdown]
# ### Visualize the result

# %%
sns.scatterplot(data = df, x = 'x', y = 'y', hue = kmedoids.predict(df))

# %% [markdown]
# ### Conclusion: KMedoid did well even with more outliers. KMeans failed

# %% [markdown]
# KMeans VS KMedoid by Di Wu is licensed under [CC BY NC SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/).

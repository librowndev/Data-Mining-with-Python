# %% [markdown]
# # Collecting data from Yahoo finance using yfinance

# %% [markdown]
# This tutorial will demonstrate how to use Python to retrieve financial data from Yahoo Finance. Using this, we may access historical market data as well as financial information about the company (for example, financial ratios).

# %% [markdown]
# Prerequisites - Python and Pip

# %% [markdown]
# ### Installation

# %%
# %pip install yfinance
# %pip install yahoofinancials
# Out:
# Requirement already satisfied: yfinance in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\librown\appdata\roaming\python\python312\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (4.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\librown\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\librown\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: yahoofinancials in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (1.20)
# Requirement already satisfied: pytz>=2022.5 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (2025.2)
# Requirement already satisfied: requests>=2.31 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (2.32.5)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (4.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (4.14.2)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from yahoofinancials) (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from beautifulsoup4>=4.11.1->yahoofinancials) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from beautifulsoup4>=4.11.1->yahoofinancials) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yahoofinancials) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yahoofinancials) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yahoofinancials) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\librown\.conda\envs\python-ds_20260112\lib\site-packages (from requests>=2.31->yahoofinancials) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Analysis

# %% [markdown]
# The yfinance package can be imported into Python programs once it has been installed. We must use the company's ticker as an example in our argument.

# %% [markdown]
# A security is given a specific set of letters called a ticker or a stock symbol for trading purposes. For instance:

# %% [markdown]
# For Amazon, it is “AMZN”
# For Facebook, it is “FB”
# For Google, it is “GOOGL”
# For Microsoft, it is "MSFT"

# %%
import yfinance as yahooFinance
 
# Here We are getting Google's financial information
GoogleInfo = yahooFinance.Ticker("GOOGL")

# %% [markdown]
# # whole python dictionary is printed here

# %%
print(GoogleInfo.info)
# Out:
# {'address1': '1600 Amphitheatre Parkway', 'city': 'Mountain View', 'state': 'CA', 'zip': '94043', 'country': 'United States', 'phone': '650-253-0000', 'website': 'https://abc.xyz', 'industry': 'Internet Content & Information', 'industryKey': 'internet-content-information', 'industryDisp': 'Internet Content & Information', 'sector': 'Communication Services', 'sectorKey': 'communication-services', 'sectorDisp': 'Communication Services', 'longBusinessSummary': 'Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in Google Play and YouTube; and devices, as well as the provision of YouTube consumer subscription services, such as YouTube TV, YouTube Music and Premium, NFL Sunday Ticket, and Google One. The Google Cloud segment offers consumption-based fees and subscriptions for AI solutions, including AI infrastructure, Vertex AI platform, and Gemini enterprise. It also provides cybersecurity, and data and analytics services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other enterprise services. The Other Bets segment sells transportation and internet services. Alphabet Inc. was incorporated in 1998 and is headquartered in Mountain View, California.', 'fullTimeEmployees': 190820, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Sundar  Pichai', 'age': 52, 'title': 'CEO & Director', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 10319413, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ruth M. Porat', 'age': 67, 'title': 'President & Chief Investment Officer', 'yearBorn': 1958, 'fiscalYear': 2024, 'totalPay': 3023363, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Dr. Lawrence Edward Page II', 'age': 52, 'title': 'Co-Founder & Director', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Sergey  Brin', 'age': 51, 'title': 'Co-Founder & Director', 'yearBorn': 1974, 'fiscalYear': 2024, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Anat  Ashkenazi', 'age': 52, 'title': 'Senior VP & CFO', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 11455556, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. J. Kent Walker', 'age': 64, 'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary', 'yearBorn': 1961, 'fiscalYear': 2024, 'totalPay': 3019696, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Philipp  Schindler', 'age': 53, 'title': 'Senior Vice President & Chief Business Officer of Google', 'yearBorn': 1972, 'fiscalYear': 2024, 'totalPay': 3051699, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': "Ms. Amie Thuener O'Toole", 'age': 50, 'title': 'Corporate Controller, Chief Accounting Officer & VP', 'yearBorn': 1975, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ellen  West', 'title': 'Vice President of Investor Relations', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Fiona Clare Cicconi', 'age': 59, 'title': 'Chief People Officer', 'yearBorn': 1966, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 7, 'boardRisk': 9, 'compensationRisk': 10, 'shareHolderRightsRisk': 10, 'overallRisk': 10, 'governanceEpochDate': 1772323200, 'compensationAsOfEpochDate': 1735603200, 'executiveTeam': [], 'maxAge': 86400, 'priceHint': 2, 'previousClose': 307.13, 'open' ...

# %% [markdown]
# The print statement produces a Python dictionary, which we can analyze and use to get the specific financial data we're looking for from Yahoo Finance. Let's take a few financial critical metrics as an example.

# %% [markdown]
# The info dictionary contains all firm information. As a result, we may extract the desired elements from the dictionary by parsing it:

# %% [markdown]
# We can retrieve financial key metrics like Company Sector, Price Earnings Ratio, and Company Beta from the above dictionary of items easily. Let us see the below code.

# %%
# display Company Sector
print("Company Sector : ", GoogleInfo.info['sector'])
 
# display Price Earnings Ratio
print("Price Earnings Ratio : ", GoogleInfo.info['trailingPE'])
 
# display Company Beta
print(" Company Beta : ", GoogleInfo.info['beta'])
# Out:
# Company Sector :  Communication Services
# Price Earnings Ratio :  27.844587
#  Company Beta :  1.112

# %% [markdown]
# There are a ton of more stuff in the information. By printing the informational keys, we can view all of them:

# %%
# get all key value pairs that are available
for key, value in GoogleInfo.info.items():
    print(key, ":", value)
# Out:
# address1 : 1600 Amphitheatre Parkway
# city : Mountain View
# state : CA
# zip : 94043
# country : United States
# phone : 650-253-0000
# website : https://abc.xyz
# industry : Internet Content & Information
# industryKey : internet-content-information
# industryDisp : Internet Content & Information
# sector : Communication Services
# sectorKey : communication-services
# sectorDisp : Communication Services
# longBusinessSummary : Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in Google Play and YouTube; and devices, as well as the provision of YouTube consumer subscription services, such as YouTube TV, YouTube Music and Premium, NFL Sunday Ticket, and Google One. The Google Cloud segment offers consumption-based fees and subscriptions for AI solutions, including AI infrastructure, Vertex AI platform, and Gemini enterprise. It also provides cybersecurity, and data and analytics services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other enterprise services. The Other Bets segment sells transportation and internet services. Alphabet Inc. was incorporated in 1998 and is headquartered in Mountain View, California.
# fullTimeEmployees : 190820
# companyOfficers : [{'maxAge': 1, 'name': 'Mr. Sundar  Pichai', 'age': 52, 'title': 'CEO & Director', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 10319413, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ruth M. Porat', 'age': 67, 'title': 'President & Chief Investment Officer', 'yearBorn': 1958, 'fiscalYear': 2024, 'totalPay': 3023363, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Dr. Lawrence Edward Page II', 'age': 52, 'title': 'Co-Founder & Director', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Sergey  Brin', 'age': 51, 'title': 'Co-Founder & Director', 'yearBorn': 1974, 'fiscalYear': 2024, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Anat  Ashkenazi', 'age': 52, 'title': 'Senior VP & CFO', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 11455556, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. J. Kent Walker', 'age': 64, 'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary', 'yearBorn': 1961, 'fiscalYear': 2024, 'totalPay': 3019696, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Philipp  Schindler', 'age': 53, 'title': 'Senior Vice President & Chief Business Officer of Google', 'yearBorn': 1972, 'fiscalYear': 2024, 'totalPay': 3051699, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': "Ms. Amie Thuener O'Toole", 'age': 50, 'title': 'Corporate Controller, Chief Accounting Officer & VP', 'yearBorn': 1975, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ellen  West', 'title': 'Vice President of Investor Relations', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Fiona Clare Cicconi', 'age': 59, 'title': 'Chief People Officer', 'yearBorn': 1966, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk : 7
# boardRisk : 9
# compensationRisk : 10
# shareHolderRightsRisk : 10
# overallRisk : 10
# governanceEpochDate : 1772323200
# compensationAsOfEpochDate : 1735603200
# executiveTeam : []
# maxAge : 86400
# priceHint : 2
# previousClose : 307.13
# open : 305.99
# dayLow : 298.27
# dayHigh : 306.0
# regularMarketPreviousClose : 307.13
# regularMarketOpen : 305.99
# regularMarketDayLow : 298.27
# regularMarketDayHigh : 306.0
# dividendRate : 0.84
# dividendYield : 0.28
# exDividendDate : 1773014400
# payoutRatio : 0.076799996
# beta : 1.112
# trailingPE : 27.844587
# forwardPE : 22.426586
# volume : 44234237
# regularMarketVolume : 44234237
# averageVolume : 32430463
# averageVolume10days : 26019000
# averageDailyVolume10Day : 26019000
# bid : 284.2
# ask : 315.78
# bidSize : 1
# askSize : 1
# marketCap : 3641197199360
# nonDilutedMarketCap : 3629179020000
# fiftyTwoWeekLow : 140.53
# fiftyTwoWeekHigh : 349.0
# allTimeHigh : 349.0
# allTimeLow : 2.401401
# priceToSalesTrailing12Months : 9.038907
# fiftyDayAverage : 317.9796
# twoHundredDayAverage : 259.8767
# trailingAnnualDividendRate : 0.83
# trailingAnnualDividendYield : 0.0027024385
# currency : USD
# tradeable : False
# enterpriseValue : 3581349986304
# profitMargins : 0.32810003
# floatShares : 10833589320
# sharesOutstanding : 5822000000
# sharesShort : 76336607
# sharesShortPriorMonth : 75948619
# sharesShortPreviousMonthDate : 1769731200
# dateShortInterest : 1772150400
# sharesPercentSharesOut : 0.0063
# heldPercentInsiders : 0.0058
# heldPercentInstitutions : 0.80817
# shortRatio : 1.9
# shortPercentOfFloat : 0.013099999
# impliedSharesOutstanding : 12097000000
# bookValue : 34.353
# priceToBook : 8.761971
# lastFiscalYearEnd : 1767139200
# nextFiscalYearEnd : 1798675200
# mostRecentQuarter : 1767139200
# earningsQuarterlyGrowth : 0.298
# netIncomeToCommon : 132169998336
# trailingEps : 10.81
# forwardEps : 13.42157
# lastSplitFactor : 20:1
# lastSplitDate : 1658102400
# enterpriseToRevenue : 8.89
# enterpriseToEbitda : 23.848
# 52WeekChange : 0.7950859
# SandP52WeekChange : 0.12811458
# lastDividendValue : 0.21
# lastDividendDate : 1773014400
# quoteType : EQUITY
# currentPrice : 301.0
# targetHighPrice : 443.0
# targetLowPrice : 185.0
# targetMeanPrice : 376.75394
# targetMedianPrice : 387.5
# recommendationMean : 1.37313
# recommendationKey : strong_buy
# numberOfAnalystOpinions : 56
# totalCash : 126843002880
# totalCashPerShare : 10.485
# ebitda : 150175006720
# totalDebt : 66995998720
# quickRatio : 1.847
# currentRatio : 2.005
# totalRevenue : 402835996672
# debtToEquity : 16.133
# revenuePerShare : 33.248
# returnOnAssets : 0.15427
# returnOnEquity : 0.35705003
# grossProfits : 240300998656
# freeCashflow : 38088376320
# operatingCashflow : 164713005056
# earningsGrowth : 0.311
# revenueGrowth : 0.18
# grossMargins : 0.59652
# ebitdaMargins : 0.37278998
# operatingMargins : 0.31568
# financialCurrency : USD
# symbol : GOOGL
# language : en-US
# region : US
# typeDisp : Equity
# quoteSourceName : Nasdaq Real Time Price
# triggerable : True
# customPriceAlertConfidence : HIGH
# shortName : Alphabet Inc.
# longName : Alphabet Inc.
# corporateActions : []
# postMarketTime : 1774051184
# regularMarketTime : 1774036803
# exchange : NMS
# messageBoardId : finmb_29096
# exchangeTimezoneName : America/New_York
# exchangeTimezoneShortName : EDT
# gmtOffSetMilliseconds : -14400000
# market : us_market
# esgPopulated : False
# regularMarketChangePercent : -1.9959
# regularMarketPrice : 301.0
# marketState : CLOSED
# sourceInterval : 15
# exchangeDataDelayedBy : 0
# averageAnalystRating : 1.4 - Strong Buy
# cryptoTradeable : False
# hasPrePostMarketData : True
# firstTradeDateMilliseconds : 1092922200000
# postMarketChangePercent : 0.5249125
# postMarketPrice : 302.58
# postMarketChange : 1.5799866
# regularMarketChange : -6.13
# regularMarketDayRange : 298.27 - 306.0
# fullExchangeName : NasdaqGS
# averageDailyVolume3Month : 32430463
# fiftyTwoWeekLowChange : 160.47
# fiftyTwoWeekLowChangePercent : 1.1418915
# fiftyTwoWeekRange : 140.53 - 349.0
# fiftyTwoWeekHighChange : -48.0
# fiftyTwoWeekHighChangePercent : -0.13753581
# fiftyTwoWeekChangePercent : 79.50859
# dividendDate : 1773619200
# earningsTimestamp : 1770238800
# earningsTimestampStart : 1776974400
# earningsTimestampEnd : 1776974400
# earningsCallTimestampStart : 1770240600
# earningsCallTimestampEnd : 1770240600
# isEarningsDateEstimate : True
# epsTrailingTwelveMonths : 10.81
# epsForward : 13.42157
# epsCurrentYear : 11.57025
# priceEpsCurrentYear : 26.014996
# fiftyDayAverageChange : -16.979614
# fiftyDayAverageChangePercent : -0.053398438
# twoHundredDayAverageChange : 41.12329
# twoHundredDayAverageChangePercent : 0.15824154
# trailingPegRatio : 2.2604

# %% [markdown]
# We can retrieve historical market prices too and display them. Additionally, we can utilize it to get earlier market data.

# %% [markdown]
# We will use historical Google stock values over the past few years as our example. It is a relatively easy assignment to complete, as demonstrated below:

# %%
# covering the past few years.
# max->maximum number of daily prices available
# for Google.
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y,
# 5y, 10y and ytd.
print(GoogleInfo.history(period="max"))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.481989    2.582758    2.381716    2.490427
# 2004-08-20 00:00:00-04:00    2.507057    2.707354    2.494399    2.688242
# 2004-08-23 00:00:00-04:00    2.748803    2.816561    2.706609    2.715296
# 2004-08-24 00:00:00-04:00    2.760964    2.769900    2.570596    2.602861
# 2004-08-25 00:00:00-04:00    2.605096    2.680548    2.578291    2.630909
# ...                               ...         ...         ...         ...
# 2026-03-16 00:00:00-04:00  304.350006  306.489990  303.019989  305.559998
# 2026-03-17 00:00:00-04:00  305.859985  311.420013  305.500000  310.920013
# 2026-03-18 00:00:00-04:00  309.269989  312.470001  306.929993  307.690002
# 2026-03-19 00:00:00-04:00  304.010010  308.059998  302.350006  307.130005
# 2026-03-20 00:00:00-04:00  305.989990  306.000000  298.269989  301.000000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2004-08-19 00:00:00-04:00  893181924        0.0           0.0
# 2004-08-20 00:00:00-04:00  456686856        0.0           0.0
# 2004-08-23 00:00:00-04:00  365122512        0.0           0.0
# 2004-08-24 00:00:00-04:00  304946748        0.0           0.0
# 2004-08-25 00:00:00-04:00  183772044        0.0           0.0
# ...                              ...        ...           ...
# 2026-03-16 00:00:00-04:00   23519700        0.0           0.0
# 2026-03-17 00:00:00-04:00   21955200        0.0           0.0
# 2026-03-18 00:00:00-04:00   20009800        0.0           0.0
# 2026-03-19 00:00:00-04:00   25075800        0.0           0.0
# 2026-03-20 00:00:00-04:00   44234237        0.0           0.0
#
# [5431 rows x 7 columns]

# %% [markdown]
# We can pass our own start and end dates.

# %%
import datetime

start = datetime.datetime(2012,5,31) 
end = datetime.datetime(2013,1,30) 
print(GoogleInfo.history(start=start, end=end))
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2012-05-31 00:00:00-04:00  14.611965  14.643734  14.370714  14.416880
# 2012-06-01 00:00:00-04:00  14.191764  14.213109  14.106383  14.171659
# 2012-06-04 00:00:00-04:00  14.152798  14.407699  14.147586  14.360540
# 2012-06-05 00:00:00-04:00  14.282605  14.349122  14.059722  14.157513
# 2012-06-06 00:00:00-04:00  14.308170  14.444432  14.236938  14.409684
# ...                              ...        ...        ...        ...
# 2013-01-23 00:00:00-05:00  18.267190  18.590098  18.262226  18.403948
# 2013-01-24 00:00:00-05:00  18.397493  18.784436  18.379374  18.719408
# 2013-01-25 00:00:00-05:00  18.634027  18.825389  18.621120  18.706005
# 2013-01-28 00:00:00-05:00  18.658598  18.753907  18.562545  18.633034
# 2013-01-29 00:00:00-05:00  18.534253  18.787417  18.529041  18.706255
#
#                               Volume  Dividends  Stock Splits
# Date
# 2012-05-31 00:00:00-04:00  118613268        0.0           0.0
# 2012-06-01 00:00:00-04:00  122193684        0.0           0.0
# 2012-06-04 00:00:00-04:00   97210692        0.0           0.0
# 2012-06-05 00:00:00-04:00   93502404        0.0           0.0
# 2012-06-06 00:00:00-04:00   83748168        0.0           0.0
# ...                              ...        ...           ...
# 2013-01-23 00:00:00-05:00  236127636        0.0           0.0
# 2013-01-24 00:00:00-05:00  135172692        0.0           0.0
# 2013-01-25 00:00:00-05:00   88946964        0.0           0.0
# 2013-01-28 00:00:00-05:00   65018916        0.0           0.0
# 2013-01-29 00:00:00-05:00   69814116        0.0           0.0
#
# [166 rows x 7 columns]

# %% [markdown]
# We can simultaneously download historical prices for many stocks:

# %% [markdown]
# The code below Pandas DataFrame including the different price data for the requested stocks. We now select the individual stock by printing df.GOOGL to have the historical market data for Google:

# %%
df = yahooFinance.download("AMZN GOOGL", start="2019-01-01", end="2020-01-01",group_by="ticker") 
print(df) 
print(df.GOOGL)
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker          GOOGL                                                  AMZN  \
# Price            Open       High        Low      Close    Volume       Open
# Date
# 2019-01-02  50.938990  52.604723  50.843776  52.301727  31868000  73.260002
# 2019-01-03  52.102873  52.875982  50.699471  50.853199  41960000  76.000504
# 2019-01-04  51.700689  53.557345  51.418025  53.461636  46022000  76.500000
# 2019-01-07  53.605455  53.691244  52.696468  53.355026  47446000  80.115501
# 2019-01-08  53.854890  54.219378  52.979624  53.823650  35414000  83.234497
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  66.957096  67.046362  66.657577  66.670464  13468000  89.690498
# 2019-12-26  66.775591  67.601271  66.724015  67.565063  23662000  90.050499
# 2019-12-27  67.640939  67.792193  67.095452  67.176781  23212000  94.146004
# 2019-12-30  67.284388  67.293809  66.343662  66.436394  19994000  93.699997
# 2019-12-31  66.242007  66.483511  66.060509  66.420532  19514000  92.099998
#
# Ticker
# Price            High        Low      Close     Volume
# Date
# 2019-01-02  77.667999  73.046501  76.956497  159662000
# 2019-01-03  76.900002  74.855499  75.014000  139512000
# 2019-01-04  79.699997  75.915497  78.769501  183652000
# 2019-01-07  81.727997  79.459503  81.475502  159864000
# 2019-01-08  83.830498  80.830498  82.829002  177628000
# ...               ...        ...        ...        ...
# 2019-12-24  89.778503  89.378998  89.460503   17626000
# 2019-12-26  93.523003  89.974998  93.438499  120108000
# 2019-12-27  95.070000  93.300499  93.489998  123732000
# 2019-12-30  94.199997  92.030998  92.344498   73494000
# 2019-12-31  92.663002  91.611504  92.391998   50130000
#
# [252 rows x 10 columns]
# Price            Open       High        Low      Close    Volume
# Date
# 2019-01-02  50.938990  52.604723  50.843776  52.301727  31868000
# 2019-01-03  52.102873  52.875982  50.699471  50.853199  41960000
# 2019-01-04  51.700689  53.557345  51.418025  53.461636  46022000
# 2019-01-07  53.605455  53.691244  52.696468  53.355026  47446000
# 2019-01-08  53.854890  54.219378  52.979624  53.823650  35414000
# ...               ...        ...        ...        ...       ...
# 2019-12-24  66.957096  67.046362  66.657577  66.670464  13468000
# 2019-12-26  66.775591  67.601271  66.724015  67.565063  23662000
# 2019-12-27  67.640939  67.792193  67.095452  67.176781  23212000
# 2019-12-30  67.284388  67.293809  66.343662  66.436394  19994000
# 2019-12-31  66.242007  66.483511  66.060509  66.420532  19514000
#
# [252 rows x 5 columns]

# %% [markdown]
# ### Save the data to CSV

# %%
#df.to_csv('data/FinanceData.csv')

# %% [markdown]
# ### Congratulations!

# %% [markdown]
# Collecting the data using Yahoo API by Ajay Sadananda is licensed under [CC BY NC SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/).

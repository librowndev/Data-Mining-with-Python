# %% [markdown]
# # Collecting data from Yahoo finance using yfinance

# %% [markdown]
# This tutorial will demonstrate how to use Python to retrieve financial data from Yahoo Finance. Using this, we may access historical market data as well as financial information about the company (for example, financial ratios).

# %% [markdown]
# Prerequisites - Python and Pip

# %% [markdown]
# ### Installation

# %%
# %pip install yfinance
# %pip install yahoofinancials

# %% [markdown]
# ### Analysis

# %% [markdown]
# The yfinance package can be imported into Python programs once it has been installed. We must use the company's ticker as an example in our argument.

# %% [markdown]
# A security is given a specific set of letters called a ticker or a stock symbol for trading purposes. For instance:

# %% [markdown]
# For Amazon, it is “AMZN”
# For Facebook, it is “FB”
# For Google, it is “GOOGL”
# For Microsoft, it is "MSFT"

# %%
import yfinance as yahooFinance
 
# Here We are getting Google's financial information
GoogleInfo = yahooFinance.Ticker("GOOGL")

# %% [markdown]
# # whole python dictionary is printed here

# %%
print(GoogleInfo.info)
# Out:
# {'address1': '1600 Amphitheatre Parkway', 'city': 'Mountain View', 'state': 'CA', 'zip': '94043', 'country': 'United States', 'phone': '650-253-0000', 'website': 'https://abc.xyz', 'industry': 'Internet Content & Information', 'industryKey': 'internet-content-information', 'industryDisp': 'Internet Content & Information', 'sector': 'Communication Services', 'sectorKey': 'communication-services', 'sectorDisp': 'Communication Services', 'longBusinessSummary': 'Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in Google Play and YouTube; and devices, as well as the provision of YouTube consumer subscription services, such as YouTube TV, YouTube Music and Premium, NFL Sunday Ticket, and Google One. The Google Cloud segment offers consumption-based fees and subscriptions for AI solutions, including AI infrastructure, Vertex AI platform, and Gemini enterprise. It also provides cybersecurity, and data and analytics services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other enterprise services. The Other Bets segment sells transportation and internet services. Alphabet Inc. was incorporated in 1998 and is headquartered in Mountain View, California.', 'fullTimeEmployees': 194668, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Sundar  Pichai', 'age': 52, 'title': 'CEO & Director', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 10906079, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ruth M. Porat', 'age': 67, 'title': 'President & Chief Investment Officer', 'yearBorn': 1958, 'fiscalYear': 2025, 'totalPay': 1015596, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Dr. Lawrence Edward Page II', 'age': 52, 'title': 'Co-Founder & Director', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Sergey  Brin', 'age': 51, 'title': 'Co-Founder & Director', 'yearBorn': 1974, 'fiscalYear': 2025, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Anat  Ashkenazi', 'age': 52, 'title': 'Senior VP & CFO', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 1087961, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. J. Kent Walker', 'age': 64, 'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary', 'yearBorn': 1961, 'fiscalYear': 2025, 'totalPay': 1015596, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Philipp  Schindler', 'age': 54, 'title': 'Senior Vice President & Chief Business Officer of Google', 'yearBorn': 1971, 'fiscalYear': 2025, 'totalPay': 1623997, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Marsida  Saraci', 'age': 46, 'title': 'Principal Accounting Officer, VP & Controller', 'yearBorn': 1979, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. James H. Friedland', 'age': 55, 'title': 'Head of Investor Relations', 'yearBorn': 1970, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Fiona Clare Cicconi', 'age': 59, 'title': 'Chief People Officer', 'yearBorn': 1966, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 8, 'boardRisk': 8, 'compensationRisk': 10, 'shareHolderRightsRisk': 10, 'overallRisk': 10, 'governanceEpochDate': 1782864000, 'compensationAsOfEpochDate': 1767139200, 'executiveTeam': [], 'maxAge': 86400, 'priceHint': 2, 'previousClose':  ...

# %% [markdown]
# The print statement produces a Python dictionary, which we can analyze and use to get the specific financial data we're looking for from Yahoo Finance. Let's take a few financial critical metrics as an example.

# %% [markdown]
# The info dictionary contains all firm information. As a result, we may extract the desired elements from the dictionary by parsing it:

# %% [markdown]
# We can retrieve financial key metrics like Company Sector, Price Earnings Ratio, and Company Beta from the above dictionary of items easily. Let us see the below code.

# %%
# display Company Sector
print("Company Sector : ", GoogleInfo.info['sector'])
 
# display Price Earnings Ratio
print("Price Earnings Ratio : ", GoogleInfo.info['trailingPE'])
 
# display Company Beta
print(" Company Beta : ", GoogleInfo.info['beta'])
# Out:
# Company Sector :  Communication Services
# Price Earnings Ratio :  26.4508
#  Company Beta :  1.247

# %% [markdown]
# There are a ton of more stuff in the information. By printing the informational keys, we can view all of them:

# %%
# get all key value pairs that are available
for key, value in GoogleInfo.info.items():
    print(key, ":", value)
# Out:
# address1 : 1600 Amphitheatre Parkway
# city : Mountain View
# state : CA
# zip : 94043
# country : United States
# phone : 650-253-0000
# website : https://abc.xyz
# industry : Internet Content & Information
# industryKey : internet-content-information
# industryDisp : Internet Content & Information
# sector : Communication Services
# sectorKey : communication-services
# sectorDisp : Communication Services
# longBusinessSummary : Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in Google Play and YouTube; and devices, as well as the provision of YouTube consumer subscription services, such as YouTube TV, YouTube Music and Premium, NFL Sunday Ticket, and Google One. The Google Cloud segment offers consumption-based fees and subscriptions for AI solutions, including AI infrastructure, Vertex AI platform, and Gemini enterprise. It also provides cybersecurity, and data and analytics services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other enterprise services. The Other Bets segment sells transportation and internet services. Alphabet Inc. was incorporated in 1998 and is headquartered in Mountain View, California.
# fullTimeEmployees : 194668
# companyOfficers : [{'maxAge': 1, 'name': 'Mr. Sundar  Pichai', 'age': 52, 'title': 'CEO & Director', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 10906079, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Ruth M. Porat', 'age': 67, 'title': 'President & Chief Investment Officer', 'yearBorn': 1958, 'fiscalYear': 2025, 'totalPay': 1015596, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Dr. Lawrence Edward Page II', 'age': 52, 'title': 'Co-Founder & Director', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Sergey  Brin', 'age': 51, 'title': 'Co-Founder & Director', 'yearBorn': 1974, 'fiscalYear': 2025, 'totalPay': 1, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Anat  Ashkenazi', 'age': 52, 'title': 'Senior VP & CFO', 'yearBorn': 1973, 'fiscalYear': 2025, 'totalPay': 1087961, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. J. Kent Walker', 'age': 64, 'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary', 'yearBorn': 1961, 'fiscalYear': 2025, 'totalPay': 1015596, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Philipp  Schindler', 'age': 54, 'title': 'Senior Vice President & Chief Business Officer of Google', 'yearBorn': 1971, 'fiscalYear': 2025, 'totalPay': 1623997, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Marsida  Saraci', 'age': 46, 'title': 'Principal Accounting Officer, VP & Controller', 'yearBorn': 1979, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. James H. Friedland', 'age': 55, 'title': 'Head of Investor Relations', 'yearBorn': 1970, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Fiona Clare Cicconi', 'age': 59, 'title': 'Chief People Officer', 'yearBorn': 1966, 'fiscalYear': 2025, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk : 8
# boardRisk : 8
# compensationRisk : 10
# shareHolderRightsRisk : 10
# overallRisk : 10
# governanceEpochDate : 1782864000
# compensationAsOfEpochDate : 1767139200
# executiveTeam : []
# maxAge : 86400
# priceHint : 2
# previousClose : 354.46
# open : 345.995
# dayLow : 341.36
# dayHigh : 348.52
# regularMarketPreviousClose : 354.46
# regularMarketOpen : 345.995
# regularMarketDayLow : 341.36
# regularMarketDayHigh : 348.52
# dividendRate : 0.88
# dividendYield : 0.25
# exDividendDate : 1780876800
# payoutRatio : 0.0641
# beta : 1.247
# trailingPE : 26.4508
# forwardPE : 23.67202
# volume : 29959283
# regularMarketVolume : 29959283
# averageVolume : 31747830
# averageVolume10days : 24946490
# averageDailyVolume10Day : 24946490
# bid : 330.0
# ask : 347.98
# bidSize : 3
# askSize : 3
# marketCap : 4231485980672
# nonDilutedMarketCap : 4227911519048
# fiftyTwoWeekLow : 186.15
# fiftyTwoWeekHigh : 408.61
# allTimeHigh : 408.61
# allTimeLow : 2.401401
# priceToSalesTrailing12Months : 10.015399
# fiftyDayAverage : 370.587
# twoHundredDayAverage : 321.656
# trailingAnnualDividendRate : 0.84
# trailingAnnualDividendYield : 0.002369802
# currency : USD
# tradeable : False
# enterpriseValue : 4170501324800
# profitMargins : 0.37919
# floatShares : 10821405400
# sharesOutstanding : 5867155790
# sharesShort : 85860436
# sharesShortPriorMonth : 82913646
# sharesShortPreviousMonthDate : 1780012800
# dateShortInterest : 1782777600
# sharesPercentSharesOut : 0.0069999998
# heldPercentInsiders : 0.011729999
# heldPercentInstitutions : 0.81009
# shortRatio : 2.13
# shortPercentOfFloat : 0.0146
# impliedSharesOutstanding : 12202573129
# bookValue : 39.514
# priceToBook : 8.775877
# lastFiscalYearEnd : 1767139200
# nextFiscalYearEnd : 1798675200
# mostRecentQuarter : 1774915200
# earningsQuarterlyGrowth : 0.812
# netIncomeToCommon : 160207994880
# trailingEps : 13.11
# forwardEps : 14.64894
# pegRatio : 1.4
# lastSplitFactor : 20:1
# lastSplitDate : 1658102400
# enterpriseToRevenue : 9.871
# enterpriseToEbitda : 25.853
# 52WeekChange : 0.8241452
# SandP52WeekChange : 0.18270898
# lastDividendValue : 0.22
# lastDividendDate : 1780876800
# quoteType : EQUITY
# currentPrice : 346.77
# targetHighPrice : 515.0
# targetLowPrice : 340.0
# targetMeanPrice : 433.51376
# targetMedianPrice : 433.0
# recommendationMean : 1.4375
# recommendationKey : strong_buy
# numberOfAnalystOpinions : 53
# totalCash : 126839996416
# totalCashPerShare : 10.469
# ebitda : 161315995648
# totalDebt : 95875997696
# quickRatio : 1.707
# currentRatio : 1.922
# totalRevenue : 422498009088
# debtToEquity : 20.026
# revenuePerShare : 34.932
# returnOnAssets : 0.14641
# returnOnEquity : 0.38884997
# grossProfits : 255053004800
# freeCashflow : 27921750016
# operatingCashflow : 174353006592
# earningsGrowth : 0.82
# revenueGrowth : 0.218
# grossMargins : 0.60368
# ebitdaMargins : 0.38181
# operatingMargins : 0.36121
# financialCurrency : USD
# symbol : GOOGL
# language : en-US
# region : US
# typeDisp : Equity
# quoteSourceName : Nasdaq Real Time Price
# triggerable : True
# customPriceAlertConfidence : HIGH
# hasPrePostMarketData : True
# firstTradeDateMilliseconds : 1092922200000
# postMarketChangePercent : -0.10669756
# postMarketPrice : 346.4
# postMarketChange : -0.36999512
# regularMarketChange : -7.6900024
# regularMarketDayRange : 341.36 - 348.52
# fullExchangeName : NasdaqGS
# averageDailyVolume3Month : 31747830
# fiftyTwoWeekLowChange : 160.62
# fiftyTwoWeekLowChangePercent : 0.8628525
# fiftyTwoWeekRange : 186.15 - 408.61
# fiftyTwoWeekHighChange : -61.839996
# fiftyTwoWeekHighChangePercent : -0.15134235
# fiftyTwoWeekChangePercent : 82.41452
# dividendDate : 1781481600
# earningsTimestamp : 1784750400
# earningsTimestampStart : 1784750400
# earningsTimestampEnd : 1784750400
# earningsCallTimestampStart : 1784750400
# earningsCallTimestampEnd : 1784750400
# isEarningsDateEstimate : False
# regularMarketChangePercent : -2.169498
# regularMarketPrice : 346.77
# marketState : CLOSED
# epsTrailingTwelveMonths : 13.11
# epsForward : 14.64894
# epsCurrentYear : 14.25218
# priceEpsCurrentYear : 24.331015
# fiftyDayAverageChange : -23.817017
# fiftyDayAverageChangePercent : -0.06426835
# twoHundredDayAverageChange : 25.113983
# twoHundredDayAverageChangePercent : 0.078077145
# sourceInterval : 15
# exchangeDataDelayedBy : 0
# averageAnalystRating : 1.4 - Strong Buy
# corporateActions : []
# postMarketTime : 1784332797
# regularMarketTime : 1784318401
# exchange : NMS
# messageBoardId : finmb_29096
# exchangeTimezoneName : America/New_York
# exchangeTimezoneShortName : EDT
# gmtOffSetMilliseconds : -14400000
# market : us_market
# esgPopulated : False
# longName : Alphabet Inc.
# cryptoTradeable : False
# shortName : Alphabet Inc.
# trailingPegRatio : 1.3653

# %% [markdown]
# We can retrieve historical market prices too and display them. Additionally, we can utilize it to get earlier market data.

# %% [markdown]
# We will use historical Google stock values over the past few years as our example. It is a relatively easy assignment to complete, as demonstrated below:

# %%
# covering the past few years.
# max->maximum number of daily prices available
# for Google.
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y,
# 5y, 10y and ytd.
print(GoogleInfo.history(period="max"))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.480508    2.581216    2.380295    2.488941
# 2004-08-20 00:00:00-04:00    2.505561    2.705737    2.492910    2.686637
# 2004-08-23 00:00:00-04:00    2.747162    2.814879    2.704993    2.713675
# 2004-08-24 00:00:00-04:00    2.759316    2.768246    2.569061    2.601307
# 2004-08-25 00:00:00-04:00    2.603541    2.678948    2.576752    2.629338
# ...                               ...         ...         ...         ...
# 2026-07-13 00:00:00-04:00  356.190002  358.130005  351.750000  352.510010
# 2026-07-14 00:00:00-04:00  351.200012  360.160004  351.089996  359.510010
# 2026-07-15 00:00:00-04:00  357.970001  373.649994  357.760010  370.920013
# 2026-07-16 00:00:00-04:00  373.059998  375.269989  352.299988  354.459991
# 2026-07-17 00:00:00-04:00  346.000000  348.519989  341.359985  346.769989
#
#                               Volume  Dividends  Stock Splits
# Date
# 2004-08-19 00:00:00-04:00  893181924        0.0           0.0
# 2004-08-20 00:00:00-04:00  456686856        0.0           0.0
# 2004-08-23 00:00:00-04:00  365122512        0.0           0.0
# 2004-08-24 00:00:00-04:00  304946748        0.0           0.0
# 2004-08-25 00:00:00-04:00  183772044        0.0           0.0
# ...                              ...        ...           ...
# 2026-07-13 00:00:00-04:00   15901700        0.0           0.0
# 2026-07-14 00:00:00-04:00   18259400        0.0           0.0
# 2026-07-15 00:00:00-04:00   28284600        0.0           0.0
# 2026-07-16 00:00:00-04:00   41158500        0.0           0.0
# 2026-07-17 00:00:00-04:00   29929300        0.0           0.0
#
# [5512 rows x 7 columns]

# %% [markdown]
# We can pass our own start and end dates.

# %%
import datetime

start = datetime.datetime(2012,5,31) 
end = datetime.datetime(2013,1,30) 
print(GoogleInfo.history(start=start, end=end))
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2012-05-31 00:00:00-04:00  14.603242  14.634993  14.362136  14.408274
# 2012-06-01 00:00:00-04:00  14.183292  14.204624  14.097962  14.163199
# 2012-06-04 00:00:00-04:00  14.144349  14.399097  14.139140  14.351967
# 2012-06-05 00:00:00-04:00  14.274080  14.340558  14.051330  14.149062
# 2012-06-06 00:00:00-04:00  14.299627  14.435807  14.228437  14.401080
# ...                              ...        ...        ...        ...
# 2013-01-23 00:00:00-05:00  18.256285  18.579001  18.251325  18.392962
# 2013-01-24 00:00:00-05:00  18.386510  18.773222  18.368402  18.708233
# 2013-01-25 00:00:00-05:00  18.622905  18.814152  18.610005  18.694839
# 2013-01-28 00:00:00-05:00  18.647461  18.742713  18.551465  18.621912
# 2013-01-29 00:00:00-05:00  18.523188  18.776201  18.517979  18.695087
#
#                               Volume  Dividends  Stock Splits
# Date
# 2012-05-31 00:00:00-04:00  118613268        0.0           0.0
# 2012-06-01 00:00:00-04:00  122193684        0.0           0.0
# 2012-06-04 00:00:00-04:00   97210692        0.0           0.0
# 2012-06-05 00:00:00-04:00   93502404        0.0           0.0
# 2012-06-06 00:00:00-04:00   83748168        0.0           0.0
# ...                              ...        ...           ...
# 2013-01-23 00:00:00-05:00  236127636        0.0           0.0
# 2013-01-24 00:00:00-05:00  135172692        0.0           0.0
# 2013-01-25 00:00:00-05:00   88946964        0.0           0.0
# 2013-01-28 00:00:00-05:00   65018916        0.0           0.0
# 2013-01-29 00:00:00-05:00   69814116        0.0           0.0
#
# [166 rows x 7 columns]

# %% [markdown]
# We can simultaneously download historical prices for many stocks:

# %% [markdown]
# The code below Pandas DataFrame including the different price data for the requested stocks. We now select the individual stock by printing df.GOOGL to have the historical market data for Google:

# %%
df = yahooFinance.download("AMZN GOOGL", start="2019-01-01", end="2020-01-01",group_by="ticker") 
print(df) 
print(df.GOOGL)
# Out:
# [*********************100%***********************]  1 of 2 completed
# Ticker          GOOGL                                                  AMZN  \
# Price            Open       High        Low      Close    Volume       Open
# Date
# 2019-01-02  50.908584  52.573323  50.813427  52.270508  31868000  73.260002
# 2019-01-03  52.071769  52.844417  50.669205  50.822842  41960000  76.000504
# 2019-01-04  51.669826  53.525374  51.387331  53.429722  46022000  76.500000
# 2019-01-07  53.573449  53.659187  52.665004  53.323170  47446000  80.115501
# 2019-01-08  53.822740  54.187011  52.947997  53.791519  35414000  83.234497
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  66.917138  67.006351  66.617798  66.630676  13468000  89.690498
# 2019-12-26  66.735741  67.560928  66.684196  67.524742  23662000  90.050499
# 2019-12-27  67.600570  67.751733  67.055408  67.136688  23212000  94.146004
# 2019-12-30  67.244232  67.253647  66.304067  66.396744  19994000  93.699997
# 2019-12-31  66.202464  66.443824  66.021074  66.380882  19514000  92.099998
#
# Ticker
# Price            High        Low      Close     Volume
# Date
# 2019-01-02  77.667999  73.046501  76.956497  159662000
# 2019-01-03  76.900002  74.855499  75.014000  139512000
# 2019-01-04  79.699997  75.915497  78.769501  183652000
# 2019-01-07  81.727997  79.459503  81.475502  159864000
# 2019-01-08  83.830498  80.830498  82.829002  177628000
# ...               ...        ...        ...        ...
# 2019-12-24  89.778503  89.378998  89.460503   17626000
# 2019-12-26  93.523003  89.974998  93.438499  120108000
# 2019-12-27  95.070000  93.300499  93.489998  123732000
# 2019-12-30  94.199997  92.030998  92.344498   73494000
# 2019-12-31  92.663002  91.611504  92.391998   50130000
#
# [252 rows x 10 columns]
# Price            Open       High        Low      Close    Volume
# Date
# 2019-01-02  50.908584  52.573323  50.813427  52.270508  31868000
# 2019-01-03  52.071769  52.844417  50.669205  50.822842  41960000
# 2019-01-04  51.669826  53.525374  51.387331  53.429722  46022000
# 2019-01-07  53.573449  53.659187  52.665004  53.323170  47446000
# 2019-01-08  53.822740  54.187011  52.947997  53.791519  35414000
# ...               ...        ...        ...        ...       ...
# 2019-12-24  66.917138  67.006351  66.617798  66.630676  13468000
# 2019-12-26  66.735741  67.560928  66.684196  67.524742  23662000
# 2019-12-27  67.600570  67.751733  67.055408  67.136688  23212000
# 2019-12-30  67.244232  67.253647  66.304067  66.396744  19994000
# 2019-12-31  66.202464  66.443824  66.021074  66.380882  19514000
#
# [252 rows x 5 columns]

# %% [markdown]
# ### Save the data to CSV

# %%
#df.to_csv('data/FinanceData.csv')

# %% [markdown]
# ### Congratulations!

# %% [markdown]
# Collecting the data using Yahoo API by Ajay Sadananda is licensed under [CC BY NC SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/).

# %% [markdown]
# # Introduction

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.arange(10)
y = np.arange(0, 1000, 100)

plt.plot(x, y)

# %%
x = np.random.normal(0.5, 0.1, (100))
x.sort()
y = x **2
print(x)
print(y)
plt.plot(x, y)
# Out:
# [0.27783147 0.30666826 0.31553663 0.31899048 0.34413485 0.35469336
#  0.36846144 0.37225767 0.37229963 0.37543918 0.3890027  0.38995162
#  0.39504116 0.3958678  0.39652088 0.40050526 0.4007744  0.40110672
#  0.40121209 0.40226412 0.40467195 0.40890644 0.40891906 0.41178778
#  0.419018   0.4196368  0.42067059 0.42150893 0.42337619 0.4377133
#  0.43808268 0.43812098 0.44079925 0.44134229 0.44320358 0.44829241
#  0.44847338 0.44974855 0.45317411 0.45372945 0.456086   0.45622601
#  0.4602225  0.46920527 0.47346616 0.47722081 0.47768602 0.47833254
#  0.48093292 0.48170983 0.48571189 0.49922071 0.50408943 0.50650121
#  0.50795261 0.50895187 0.51414858 0.51645759 0.51924422 0.52052802
#  0.52156031 0.5232797  0.52673963 0.52857401 0.53259295 0.53582801
#  0.55137652 0.55698517 0.55868134 0.56045442 0.56181452 0.56451551
#  0.56829719 0.56883521 0.56979423 0.57126066 0.57210117 0.57898884
#  0.5814641  0.58746059 0.58944178 0.59357852 0.59358058 0.59406721
#  0.59420331 0.60100886 0.60163509 0.60471192 0.60611207 0.60777646
#  0.61186533 0.61828971 0.62533101 0.62573275 0.63045912 0.64411022
#  0.65823957 0.66383139 0.67006402 0.77866548]
# [0.07719033 0.09404542 0.09956337 0.10175492 0.11842879 0.12580738
#  0.13576383 0.13857577 0.13860702 0.14095458 0.1513231  0.15206226
#  0.15605752 0.15671132 0.15722881 0.16040446 0.16062012 0.1608866
#  0.16097114 0.16181642 0.16375938 0.16720448 0.1672148  0.16956918
#  0.17557608 0.17609505 0.17696375 0.17766978 0.1792474  0.19159293
#  0.19191643 0.19194999 0.19430398 0.19478302 0.19642941 0.20096609
#  0.20112837 0.20227376 0.20536678 0.20587042 0.20801444 0.20814217
#  0.21180475 0.22015358 0.22417021 0.2277397  0.22818393 0.22880202
#  0.23129647 0.23204436 0.23591604 0.24922132 0.25410616 0.25654348
#  0.25801586 0.25903201 0.26434876 0.26672844 0.26961456 0.27094942
#  0.27202516 0.27382165 0.27745464 0.27939048 0.28365525 0.28711166
#  0.30401607 0.31023248 0.31212484 0.31410916 0.31563555 0.31867777
#  0.32296169 0.32357349 0.32466547 0.32633874 0.32729975 0.33522807
#  0.3381005  0.34510995 0.34744161 0.35233546 0.3523379  0.35291585
#  0.35307758 0.36121165 0.36196478 0.36567651 0.36737184 0.36939222
#  0.37437919 0.38228216 0.39103887 0.39154148 0.3974787  0.41487797
#  0.43327933 0.44067211 0.44898579 0.60631993]

# %%
plt.plot(x, y, 'o')

# %%
x = np.arange(100)
y = x**3
plt.plot(y, '1')

# %%
markers = ['o', '*', '.', ',', 'x', 'X', '+', 'P', 's', 'D', 'd', 'p', 'H', 'h', 'v', '^', '<', '>', '1', '2', '3', '4', '|', '_']

for m in markers:
  print(m)
  plt.plot(y, m)
  plt.show()
# Out:
# o
# *
# .
# ,
# x
# X
# +
# P
# s
# D
# d
# p
# H
# h
# v
# ^
# <
# >
# 1
# 2
# 3
# 4
# |
# _

# %%
y = np.array([1, 3, 13])
line = ['-',':','--','-.']
for l in line:
  print(l)
  l = 'o' + l + 'r'
  plt.plot(y, l)
  plt.show()
# Out:
# -
# :
# --
# -.

# %%
color = ['r','g','b','c','m','y','k','w']
for c in color:
  print(c)
  c = 'o:' + c
  plt.plot(y, c)
  plt.show()
# Out:
# r
# g
# b
# c
# m
# y
# k
# w

# %%
plt.plot(y, marker = '^', ms = 30)

# %%
x = np.arange(10)
y1 = x*2
y2 = x**2
plt.plot(y1)
plt.plot(y2)

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %%
plt.plot(x, y1, label = 'double')
plt.plot(x, y2, label = 'square')
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()
plt.legend(['1st', '2nd'])

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(2, 1, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(1, 2, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.plot(x, y, 'o')

# %%
plt.scatter(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='hot')

plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %%
plt.scatter(x, y, c = colors, cmap = 'hot', alpha = 0.5, s = sizes)
plt.colorbar()

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 13 artists>

# %%
plt.hist(x)
# Out:
# (array([2., 1., 2., 2., 3., 0., 2., 0., 0., 1.]),
#  array([ 2. ,  3.5,  5. ,  6.5,  8. ,  9.5, 11. , 12.5, 14. , 15.5, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'])
plt.legend()

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'], explode = [0.0, 0.2, 0])
plt.legend()

# %%
x = np.arange(10)
alpha = (x+1)**2/2
delta = (x+2)**2
omicron = (x+3)**2 * 3

plt.plot(x, alpha, label = "Alpha")
plt.plot(x, delta, label = "Delta")
plt.plot(x, omicron, label = "Omicron")
plt.legend()

# %% [markdown]
# # Practice

# %%
from sklearn.datasets import fetch_california_housing

california_housing = fetch_california_housing(as_frame=True)

# %%
print(california_housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib:
# https://lib.stat.cmu.edu/datasets/houses.zip
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %%
# file = '/content/sample_data/california_housing_train.csv'
# df = pd.read_csv(file)
# df.info()
california_housing.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# play with this dataset using the plots we learned so far

# %% [markdown]
# 2 - Matplotlib by Di Wu is licensed under [CC BY NC SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/).
